# %%
import MyLibrary as ml
import pandas as pd
path=ml.dataB101['Header']
data=ml.dataFrame.loadDataSetFromMat(path)
print(data['header'][0])
data=pd.DataFrame(data['header'][0])
data.head()
# Out:
# [(array([[5]], dtype=uint8), array([[12288000]], dtype=int32), array([[62]], dtype=uint8), array([[32768]], dtype=uint16), array(['Baseband'], dtype='<U8'), array(['Continuous'], dtype='<U10'), array([[0]], dtype=uint8), array([[92876.8]]), array([[4.8828125e-06]]), array([[100]], dtype=uint8), array(['0/0/0'], dtype='<U5'), array(['0:0:0'], dtype='<U5'), array([[2.69447251e+02, 2.69239027e+02, 2.68651150e+02, 2.69082949e+02,
#          2.68771414e+02, 2.69054907e+02, 2.68865842e+02, 2.69326017e+02,
#          2.68916729e+02, 2.67985511e+02, 2.68746192e+02, 2.69209343e+02,
#          2.69440298e+02, 2.69654130e+02, 2.68837618e+02, 2.69431320e+02,
#          2.68977361e+02, 2.68952647e+02, 2.69286163e+02, 2.69205647e+02,
#          2.69097446e+02, 2.69230423e+02, 2.68797655e+02, 2.69355603e+02,
#          2.68907681e+02, 2.69735005e+02, 2.69339307e+02, 2.68943034e+02,
#          2.68959622e+02, 2.69180853e+02, 2.69637961e+02, 2.69196324e+02,
# ...
